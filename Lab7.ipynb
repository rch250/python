# %% [markdown]
# ## IMPORTS

# %%
import pyodbc
import pandas as pd
import seaborn as sns

# %% [markdown]
# # From an MS SQL Server Database
# # NAMES
# ### Open a database connection

# %%
connection = pyodbc.connect(
    server = "cisdbss.pcc.edu",
    user = "275student",
    password = "275student",
    database = "NAMES",
    driver = "{ODBC Driver 17 for SQL Server}"
)

connection

# %% [markdown]
# ### Load the Dataframe for  NAMES

# %%
df = pd.read_sql_query("""
SELECT *
FROM all_data
WHERE Name = 'Robert'
""", connection)

df
# Out:
#             ID     Rank  NameCount  NameID    Name Metaphone  \
# 0     120329.0    609.0      116.0   609.0  Robert      RBRT
# 1     124692.0      4.0    28738.0   609.0  Robert      RBRT
# 2     129692.0    614.0      122.0   609.0  Robert      RBRT
# 3     134244.0      4.0    31741.0   609.0  Robert      RBRT
# 4     139289.0    515.0      168.0   609.0  Robert      RBRT
# ..         ...      ...        ...     ...     ...       ...
# 195  1745031.0     61.0     6926.0   609.0  Robert      RBRT
# 196  1772060.0  12874.0        8.0   609.0  Robert      RBRT
# 197  1778439.0     62.0     6679.0   609.0  Robert      RBRT
# 198  1808397.0  16008.0        6.0   609.0  Robert      RBRT
# 199  1811517.0     61.0     6572.0   609.0  Robert      RBRT
#
#      YearGenderTotalID    Year Gender      Total
# 0                  1.0  1915.0      F   983874.0
# 1                  2.0  1915.0      M   848603.0
# 2                  3.0  1916.0      F  1044323.0
# ...

# %% [markdown]
# ### Display the dataframe info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 200 non-null    float64
#  1   Rank               200 non-null    float64
#  2   NameCount          200 non-null    float64
#  3   NameID             200 non-null    float64
#  4   Name               200 non-null    object
#  5   Metaphone          200 non-null    object
#  6   YearGenderTotalID  200 non-null    float64
#  7   Year               200 non-null    float64
#  8   Gender             200 non-null    object
#  9   Total              200 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ## 1. Year vs Namecount

# %% [markdown]
# ### Relational: Line

# %%
g = sns.relplot(data=df, kind='line',
            x='Year', y='NameCount', hue='Gender')
g

# %% [markdown]
# ### save files

# %%
g.savefig('NamesLineChart.png')
g.savefig('NamesLineChart.svg')

# %% [markdown]
# ### Relational: Scatter

# %%
g = sns.relplot(data=df, kind='scatter',
            x='Year', y='NameCount', hue='Gender')
g

# %% [markdown]
# ### save files

# %%
g.savefig('NamesScatterChart.png')
g.savefig('NamesScatterChart.svg')

# %% [markdown]
# ### Distribution: Histogram

# %%
g = sns.displot(data=df, kind='hist', x='Year', y='NameCount', hue='Gender')

# %% [markdown]
# ### save files

# %%
g.savefig('NamesHistChart.png')
g.savefig('NamesHistChart.svg')

# %% [markdown]
# ### Category: Bar

# %%
g = sns.catplot(data=df.query('Year >= 1910 and Year <= 1915'), 
            kind='bar', x='Year', y='NameCount', hue='Gender', orient='h')
g

# %% [markdown]
# ### Save files

# %%
g.savefig('NamesCatChart.png')
g.savefig('NamesCatChart.svg')

# %% [markdown]
# ## 2. Year Vs Rank

# %% [markdown]
# ### Relational: Line

# %%
g = sns.relplot(data=df, kind='line',
            x='Year', y='Rank', hue='Gender')
g

# %% [markdown]
# ### save files

# %%
g.savefig('NamesLine2Chart.png')
g.savefig('NamesLine2Chart.svg')

# %% [markdown]
# ### Distribution: Histogram

# %%
g = sns.displot(data=df.query('Year >= 1980 and Year <= 2000'), 
                kind='hist', x='Year', y='Rank', hue='Gender')
ax.tick_params('x', labelrotation=90)

# %% [markdown]
# ### save files

# %%
g.savefig('Nameshist2Chart.png')
g.savefig('Nameshist2Chart.svg')

# %% [markdown]
# ### Category: BAR

# %%
g.savefig('IMDBscatterChart.png')
g.savefig('IMDBscatterChart.svg')

# %%
g = sns.catplot(data=df, 
            kind='bar', x='Year', y='Rank', hue='Gender', orient='h')
g

# %% [markdown]
# ### Save files

# %%
g = sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
            kind='bar', x='DeathRate', y='Year', hue='AgeGroup', orient='h')
g

# %%
g.savefig('NamesCat2Chart.png')
g.savefig('NamesCat2Chart.svg')

# %%
g.savefig('IMDBcatChart.png')
g.savefig('IMDBcatChart.svg')

# %% [markdown]
# ###

# %% [markdown]
# # FROM AMANZON CSV

# %% [markdown]
# ### Load the data frame

# %%
df = pd.read_csv("Amazon_Best_Seller_2021_June.csv")
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...     1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...     1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...     1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...    27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...     1 Sellers   #5
# ..                                                 ...           ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...    10 Sellers  #95
# ...

# %%
df = pd.read_csv("Amazon_Best_Seller_2021_June.csv")
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link No of Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...     1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...     1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...     1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...    27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...     1 Sellers   #5
# ..                                                 ...           ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...    10 Sellers  #95
# ...

# %% [markdown]
# ### Rename the columns

# %%
df = df.rename(columns={"No of Sellers": "Sellers", "Reviews Count": "Reviews"})                     
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link     Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...   1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...   1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...   1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...  27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...   1 Sellers   #5
# ..                                                 ...         ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...  10 Sellers  #95
# ...

# %%
df = df.rename(columns={"No of Sellers": "Sellers", "Reviews Count": "Reviews"})                     
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link     Sellers Rank  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...   1 Sellers   #1
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...   1 Sellers   #2
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...   1 Sellers   #3
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...  27 Sellers   #4
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...   1 Sellers   #5
# ..                                                 ...         ...  ...
# 702  https://www.amazon.com/gp/offer-listing/B007DW...  10 Sellers  #95
# ...

# %% [markdown]
# ### Clean the data

# %%
df['Sellers'] = df.Sellers.replace( { "Sellers": "" }, regex=True)
df['Rank'] = df.Rank.replace({ "[#]": "" }, regex=True)
df['Price'] = df.Price.replace({ "[$]": ""}, regex=True )
df['Reviews'] = df.Reviews.replace({ ",": ""}, regex=True )
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link Sellers Rank  Rating  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...      1     1     4.7
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...      1     2     4.7
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...      1     3     4.7
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...     27     4     4.8
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...      1     5     4.7
# ..                                                 ...     ...  ...     ...
# ...

# %% [markdown]
# ## Convert the data types

# %%
df['ASIN'] = df['ASIN'].astype('str')
df['Category'] = df['Category'].astype('str')
df['Sellers'] =df['Sellers'].astype('int','ignore')
df['Rank'] =df['Rank'].astype('int')
df['Rating'] =df['Rating'].astype('float')
df['Reviews'] =df['Reviews'].astype('int')
df['Price'] =df['Price'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707 entries, 0 to 706
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ASIN          707 non-null    object
#  1   Category      707 non-null    object
#  2   Product Link  707 non-null    object
#  3   Sellers       707 non-null    int32
#  4   Rank          707 non-null    int32
#  5   Rating        707 non-null    float64
#  6   Reviews       707 non-null    int32
#  7   Price         707 non-null    float64
# dtypes: float64(2), int32(3), object(3)
# memory usage: 36.0+ KB

# %% [markdown]
# ### Your visualizations must include at least one relplot, at least one displot, and at least one catplot.
# ### Save each visualization as a separate file. Include at least one PNG and at least one SVG.

# %% [markdown]
# ### Resummarize the df to plot

# %%
df
# Out:
#            ASIN      Category  \
# 0    B079QHML21   Electronics
# 1    B07FZ8S74R   Electronics
# 2    B07XJ8C8F5   Electronics
# 3    B07WVFCVJN   Electronics
# 4    B08YT2N5SX   Electronics
# ..          ...           ...
# 702  B007DW6F34  Toys & Games
# 703  B01N16VX79  Toys & Games
# 704  B09197N995  Toys & Games
# 705  B015CCR1FW  Toys & Games
# 706  B07TS96J7Q  Toys & Games
#
#                                           Product Link  Sellers  Rank  Rating  \
# 0    https://www.amazon.com/gp/offer-listing/B079QH...        1     1     4.7
# 1    https://www.amazon.com/gp/offer-listing/B07FZ8...        1     2     4.7
# 2    https://www.amazon.com/gp/offer-listing/B07XJ8...        1     3     4.7
# 3    https://www.amazon.com/gp/offer-listing/B07WVF...       27     4     4.8
# 4    https://www.amazon.com/gp/offer-listing/B08YT2...        1     5     4.7
# ..                                                 ...      ...   ...     ...
# ...

# %%
cat_group = df.groupby('Category').sum('Sellers')
cat_group
# Out:
#                            Sellers  Rank  Rating   Reviews     Price
# Category
# Books                          146  2899   327.2   1812958    804.67
# Camera & Photo                 385  5050   432.4    721754   5063.08
# Clothing, Shoes & Jewelry      374  5050   447.3   2868554   1760.87
# Electronics                    908  8646   678.7  11309903  19907.48
# Gift Cards                     100  5050   480.7  33486769   4400.74
# Toys & Games                  1288  4775   441.8   1680303   1639.33
# Video Games                   2691  4839   439.5   2562960   5794.08

# %% [markdown]
# ## Visualization 1: Price Vs Reviews

# %% [markdown]
# ### Relational: Line

# %%
g = sns.relplot(data=df, kind='line',
            x='Price', y='Reviews', hue='Category')
g

# %% [markdown]
# ### Save the files

# %%
g.savefig('AmazonlineChart.png')
g.savefig('AmazonlineChart.svg')

# %% [markdown]
# ### Relational: Scatter

# %%
g = sns.relplot(data=df, kind='scatter',
            x='Price', y='Reviews', hue='Category')
g

# %% [markdown]
# ### Save the files

# %%
g.savefig('AmazonscatterChart.png')
g.savefig('AmazonscatterChart.svg')

# %% [markdown]
# ### Distribution: Histogram

# %%
g = sns.displot(data=df, kind='hist', x='Price', hue='Category')

# %% [markdown]
# ### Save the files

# %%
g.savefig('AmazondisHistChart.png')
g.savefig('AmazondisHistChart.svg')

# %% [markdown]
# ### Category: Bar

# %%
g = sns.catplot(data=df, 
            kind='bar', x='Reviews', y='Price', hue='Category', orient='h')
g

# %% [markdown]
# ### Save the files

# %%
g.savefig('AmazoncatChart.png')
g.savefig('AmazoncatChart.svg')

# %% [markdown]
# ### Subplots: Lines

# %%
g=sns.relplot(data=df, 
            kind='line', x='Reviews', y='Price', hue='Category', 
            height=4, aspect=1.25, 
            col='Category', col_wrap=2, legend=False)
g

# %%
g.savefig('Amazonlinesubplot.png')
g.savefig('Amazonlinesubplot.svg')

# %% [markdown]
# ### Subplots: Scatter

# %%
g=sns.relplot(data=df, 
            kind='scatter', x='Reviews', y='Price', hue='Category', 
            height=4, aspect=1.25, 
            col='Category', col_wrap=2, legend=False)
g.fig.suptitle('Amazon Categories', y=1.025)
g

# %%
g.savefig('Amazonscatterubplot.png')
g.savefig('Amazonscattersubplot.svg')

# %% [markdown]
# ## Visualization 2: Sellers vs Rank

# %% [markdown]
# ### Relational: Scatter

# %%
g = sns.relplot(data=df, kind='scatter',
            x='Sellers', y='Rank', hue='Category', aspect=2)
g
for ax in g.axes.flat:
    ax.tick_params('x', labelrotation=90)
    ax.tick_params('y', labelrotation=90)

# %% [markdown]
# ### Save files

# %%
g.savefig('Amazonscatter2plot.png')
g.savefig('Amazonscatter2plot.svg')

# %% [markdown]
# ### Distribution: Histogram

# %%
g = sns.displot(data=df, kind='hist', x='Sellers', hue='Category', aspect=2)
for ax in g.axes.flat:
    ax.tick_params('x', labelrotation=90)

# %%
g.savefig('Amazonshist2plot.png')
g.savefig('Amazonshist2plot.svg')

# %% [markdown]
# ### Category: Bar

# %%
g = sns.catplot(data=df, 
            kind='bar', x='Rank', y='Sellers', hue='Category', orient='h')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8168/1825515518.py in <module>
# ----> 1 g = sns.catplot(data=df,
#       2             kind='bar', x='Rank', y='Sellers', hue='Category', orient='h')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
# ...

# %% [markdown]
# ### Save files

# %%
g.savefig('Amazonshist2plot.png')
g.savefig('Amazonshist2plot.svg')
